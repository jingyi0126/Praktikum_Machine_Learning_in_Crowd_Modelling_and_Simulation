# %% [markdown]
# # TODO: Task 1 - Approximating Functions

# %%
# All imports
import numpy as np
import matplotlib.pyplot as plt
from scipy.linalg import lstsq
from scipy.spatial.distance import cdist
from utils import *
from sklearn.metrics import mean_squared_error
# Load datasets with linear and non-linear function data
data_A = np.loadtxt('../../data/linear_function_data.txt')
data_B = np.loadtxt('../../data/nonlinear_function_data.txt')

# %% [markdown]
# ### TODO: Part 1 - Approximating function in dataset A with a linear function

# %%
plot_linear(data_A, name="Dataset A")
# Out:
# MSE=1.0604702468524868e-10

# %% [markdown]
# ### TODO: Part 2 -  Approximating function in dataset B with a linear function

# %%
plot_linear(data_B, name="Dataset B")
# Out:
# MSE=0.7625586438353887

# %% [markdown]
# ### TODO: Part 3.1 - Approximating function in dataset B with radial basis functions

# %%
np.min(data_B[:, 0]), np.max(data_B[:, 0])
# Out:
# (-3.053764380426305, 3.9586027040379634)

# %%
num_x_l_list = [5, 10, 15, 20, 25]  # Example list of number of centers to try
eps_list = [0.1, 0.5, 1.0, 1.5, 2.0]  # Example list of epsilon values to try
for num_x_l in num_x_l_list:
    x_l = np.linspace(-3.1, 4, num_x_l).reshape(-1, 1)
    for eps in eps_list:
        plot_nonlinear(data_B, x_l=x_l, eps=eps, cond=1e-5, name="Dataset B")
# Out:
# MSE=0.5806968441218574
# MSE=0.31695681791480507
# MSE=0.32005164936322306
# MSE=0.31876155236830106
# MSE=0.35031404613631106
# MSE=0.5540706027138002
# MSE=0.07391010684281253
# MSE=0.00021232035649553058
# MSE=4.012929385921161e-05
# MSE=0.00459592026569729
# MSE=0.4020403684182205
# MSE=4.892279493270282e-05
# MSE=4.986963463585526e-07
# MSE=1.1717956492494681e-05
# MSE=0.0017526084532948282
# MSE=0.2734040942523328
# MSE=6.536477033052612e-06
# MSE=1.5759523321842006e-09
# MSE=1.1070064797314452e-05
# MSE=0.0017473239597517588
# MSE=0.15715353610369134
# MSE=5.646942614312926e-07
# MSE=2.4982523944804406e-09
# MSE=1.0796042365986041e-05
# MSE=0.0017265410689031567

# %% [markdown]
# ### TODO: Part 3.2 - Approximating function in dataset A with radial basis functions (Why is it not a good idea?)

# %%
x_l = np.linspace(-3.1, 4, 15).reshape(-1, 1)

# %%
plot_nonlinear(data_A, x_l, eps=0.4, cond=1e-5, name="Dataset A")
# Out:
# MSE=2.570561857986066e-05
